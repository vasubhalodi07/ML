# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import the dataset
dataset = pd.read_csv('/content/drive/MyDrive/Work/ML/Algorithms/Linear Regression/train.csv')

# %%
dataset
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
dataset.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
x_value = dataset.iloc[0:700, 0:1]
x_value
# Out:
#         x
# 0    24.0
# 1    50.0
# 2    15.0
# 3    38.0
# 4    87.0
# ..    ...
# 695  58.0
# 696  93.0
# 697  82.0
# 698  66.0
# 699  97.0
#
# [700 rows x 1 columns]

# %%
y_value = dataset.iloc[0:700, 1:2]
y_value
# Out:
#              y
# 0    21.549452
# 1    47.464463
# 2    17.218656
# 3    36.586398
# 4    87.288984
# ..         ...
# 695  58.595006
# 696  94.625094
# 697  88.603770
# 698  63.648685
# 699  94.975266
#
# [700 rows x 1 columns]

# %%
x_value.boxplot(column=['x'])

# %%
y_value.boxplot(column=['y'])

# %%
plt.scatter(x_value,y_value)
plt.title('Scatter Plot')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
# Designing the single var linear regression Model

def hypothesis(theta_array, x):
  return theta_array[0] + theta_array[1] * x;

# %%
def costfunction(theta_array, x_value, y_value, m):
  sum = 0
  for i in range(m):
    sum += ((theta_array[0] + theta_array[1] * x_value[i]) - (y_value)) ** 2
  return sum/(2 * m)

# %%
# Gradient Descent
def gradientDescent(theta_array,X,Y,alpha,m):
  sum_0 = 0  #theta[0]
  sum_1 = 1  #theta[1] 

  for i in range(m):
    sum_0 = sum_0 + ((theta_array[0] + theta_array[1] * X[i]) - Y[i])
    sum_1 = sum_1 + X[i] * ((theta_array[0] + theta_array[1] * X[i]) - Y[i])

  new_theta0 = theta_array[0] - alpha * (sum_0 / m)
  new_theta1 = theta_array[1] - alpha * (sum_1 / m)
  improved_thetas = [new_theta0, new_theta1]
  print(improved_thetas)
  return (improved_thetas)

# %%
#Training Process 
def training(x_train,y_train,alpha,iters):
  m=x_train.size
  theta_0=0
  theta_1=0
  cost_values=[]
  theta_array=[theta_0,theta_1]

  for i in range(iters):
    theta_array=gradientDescent(theta_array,x_train,y_train,alpha,m)
    loss=costfunction(theta_array,x_train,y_train,m)
    cost_values.append(loss)
    ynew=theta_array[0]+theta_array[1]*x_train
    
    plt.scatter(x_train,y_train)
    plt.plot(x_train,ynew,'r')
    plt.show() 

  x=np.arange(0,iters,step=1)
  plt.plot(x,cost_values,"-g")
  plt.xlabel("number of iterations")
  plt.ylabel("Cost values")
  plt.title("Costfunction vs Iterations Curve")
  plt.show()
  return theta_array   #final theta values

# %%
clean_dataset = dataset.dropna()

# %%
clean_dataset
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %%
x_new = clean_dataset['x']
y_new = clean_dataset['y']

# %%
type(x_new)
# Out:
# pandas.core.series.Series

# %%
x_train = x_new.values.reshape(x_new.size)

# %%
x_train.shape
# Out:
# (699,)

# %%
y_train = y_new.values.reshape(y_new.size)

# %%
alpha = 0.0001
iter = 50

# %%
theta_array_final = training(x_train, y_train, alpha, iter)
# Out:
# [0.004993986917045777, 0.33354231539033746]
# [0.008319285687753765, 0.555703283089295]
# [0.010533129263240532, 0.7036770033569612]
# [0.012006671159583253, 0.8022371746281115]
# [0.012987123843704951, 0.8678846970413571]
# [0.013639146954150931, 0.9116102471039331]
# [0.014072414557537992, 0.9407343327318921]
# [0.014359976740666365, 0.9601328900073948]
# [0.014550489629328705, 0.9730536106138535]
# [0.014676361379091049, 0.981659669189487]
# [0.014759177936842343, 0.9873918812339108]
# [0.014813316952126267, 0.9912099239119984]
# [0.01484835487796847, 0.9937530048537521]
# [0.01487067025713916, 0.9954468780618807]
# [0.014884511615450591, 0.9965751234911823]
# [0.014892708748394663, 0.9973266239008358]
# [0.014897146484469291, 0.997827187536846]
# [0.014899080242476333, 0.9981606109025646]
# [0.014899346213278458, 0.9983827079386279]
# [0.014898501354567798, 0.9985306543724797]
# [0.014896916636519339, 0.9986292116650595]
# [0.014894839149482227, 0.9986948725655357]
# ...

# %%
# prediction
predict = hypothesis(theta_array_final, 20)

# %%
predict
# Out:
# 19.99135173748821
